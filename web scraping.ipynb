# %%
from bs4 import BeautifulSoup
import requests

# %%
url= "https://boston.craigslist.org/search/sof"

# %%
response= requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data= response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  jobs - craigslist</title>\n    <script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n\n    <meta name="description" content="">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n        <link rel="canonical" href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=ebf48c6109c06a8e6dbee442f06f0084">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=fd4f01ec1e3db22cf5a5494aba60e24c">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "4";\nvar areaRegion = "MA";\nvar catAbb = "sof";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "jjj";\nvar sectionBase = "jjj";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n  ...

# %%
soup=BeautifulSoup(data,'html.parser')

# %%
tags = soup.find_all('a')

# %%
for tag in tags :
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof?sort=date&
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://boston.craigslist.org/gbs/sof/d/roxbury-devops-engineer/7326968311.html
# https://boston.craigslist.org/gbs/sof/d/roxbury-devops-engineer/7326968311.html
# #
# https://boston.craigslist.org/gbs/sof/d/roxbury-software-engineer/7326968266.html
# https://boston.craigslist.org/gbs/sof/d/roxbury-software-engineer/7326968266.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-data-science-lead-stealth/7326963835.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-data-science-lead-stealth/7326963835.html
# #
# https://boston.craigslist.org/bmw/sof/d/marlborough-implementation-consultnat/7326810798.html
# https://boston.craigslist.org/bmw/sof/d/marlborough-implementation-consultnat/7326810798.html
# #
# https://boston.craigslist.org/gbs/sof/d/auburndale-visual-studio-programming/7326520827.html
# https://boston.craigslist.org/gbs/sof/d/auburndale-visual-studio-programming/7326520827.html
# #
# https://boston.craigslist.org/gbs/sof/d/malden-in-class-qa-ba-training/7326485408.html
# https://boston.craigslist.org/gbs/sof/d/malden-in-class-qa-ba-training/7326485408.html
# #
# https://boston.craigslist.org/gbs/sof/d/roxbury-software-engineer/7324312428.html
# https://boston.craigslist.org/gbs/sof/d/roxbury-software-engineer/7324312428.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7323959337.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7323959337.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7323959163.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7323959163.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7323958513.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7323958513.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-app-developer-local-only/7323902293.html
# https://boston.craigslist.org/gbs/sof/d/boston-app-developer-local-only/7323902293.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7323379843.html
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7323379843.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7323379765.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7323379765.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-vp-engineering/7323110648.html
# https://boston.craigslist.org/gbs/sof/d/boston-vp-engineering/7323110648.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-data-analyst/7323077425.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-data-analyst/7323077425.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7321021998.html
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7321021998.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7321019984.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7321019984.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7321019962.html
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7321019962.html
# #
# https://boston.craigslist.org/gbs/sof/d/austin-principal-ios-engineer-music/7320982917.html
# https://boston.craigslist.org/gbs/sof/d/austin-principal-ios-engineer-music/7320982917.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7320515970.html
# https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7320515970.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7320481366.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7320481366.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7320479750.html
# https://boston.craigslist.org/gbs/sof/d/andover-devops-engineer/7320479750.html
# #
# https://boston.craigslist.org/sob/sof/d/boston-part-time-website-project-manager/7320269650.html
# https://boston.craigslist.org/sob/sof/d/boston-part-time-website-project-manager/7320269650.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7319977405.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7319977405.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-frontend-developer/7317823192.html
# https://boston.craigslist.org/gbs/sof/d/boston-frontend-developer/7317823192.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7317785167.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7317785167.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7317784867.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7317784867.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7317784594.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7317784594.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-python-full-stack-developer/7317756899.html
# https://boston.craigslist.org/gbs/sof/d/boston-python-full-stack-developer/7317756899.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7317676935.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7317676935.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7317162822.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7317162822.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7314475974.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7314475974.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7314475787.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7314475787.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7314306065.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7314306065.html
# #
# https://boston.craigslist.org/nos/sof/d/beverly-it-systems-analyst/7313807037.html
# https://boston.craigslist.org/nos/sof/d/beverly-it-systems-analyst/7313807037.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-back-end-developer/7313681646.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-back-end-developer/7313681646.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-developer/7313678816.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-developer/7313678816.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7313471881.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7313471881.html
# #
# https://providence.craigslist.org/sof/d/providence-senior-web-developer-remote/7323510431.html
# https://providence.craigslist.org/sof/d/providence-senior-web-developer-remote/7323510431.html
# #
# https://providence.craigslist.org/sof/d/providence-software-engineer-engineer/7314083206.html
# https://providence.craigslist.org/sof/d/providence-software-engineer-engineer/7314083206.html
# #
# https://capecod.craigslist.org/sof/d/woods-hole-software-engineer/7314741888.html
# https://capecod.craigslist.org/sof/d/woods-hole-software-engineer/7314741888.html
# #
# #page-top
# #page-top
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://www.craigslist.org/about/help/
# https://www.craigslist.org/about/scams
# https://www.craigslist.org/about/privacy.policy
# https://forums.craigslist.org/?forumID=8
# https://www.craigslist.org/about/terms.of.use
# https://www.craigslist.org/about/

# %%
titles= soup.find_all('a',{'class':'result-title'})

# %%
for title in titles :
    print(title.text)
# Out:
# DevOps Engineer
# Software Engineer
# Data Science Lead - Stealth Startup
# Implementation Consultnat
# Visual Studio Programming Expert /BASIC / C /Webforms /API
# In Class QA/BA Training & Placement in Boston Area
# Software Engineer
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# App Developer - LOCAL ONLY
# DevOps Engineer
# Software Engineer
# VP, Engineering
# Senior Data Analyst
# DevOps Engineer
# Software Engineer
# DevOps Engineer
# Principal iOS Engineer, Music Tech (Side Gig, Big Equity, Proven Team)
# Best In-Demand IT Skills & Job Training Program
# Software Engineer
# DevOps Engineer
# Part-time Website Project Manager
# Software Engineer
# Frontend Developer
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Python Full Stack Developer
# Software Engineer
# Software Engineer
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Software Engineer
# IT Systems Analyst
# Back-End Developer
# Full Stack Developer
# Software Engineer
# Senior Web Developer (remote, contract, US-onshore, single project)
# Software Engineer - Engineer Interviewer (Contract-Fully Remote!)
# Software Engineer

# %%
addresses= soup.find_all('span',{'class':"result-hood"})

# %%
for addr in addresses :
    print(addr.text)
# Out:
#  (Marlborough)
#  (Auburndale)
#  (Malden, MA)
#  (Boston)
#  (boston: boston/cambridge/brookline)
#  (boston: boston/cambridge/brookline)
#  (Remote)
#  (Boston, MA)
#  (Boston, MA)
#  (Remote)
#  (Beverly)
#  (Cambridge)
#  (Cambridge)
#  (Remote)

# %%
jobs= soup.find_all('div',{'class':'result-info'})

# %%
for job in jobs:
    title=job.find('a',{'class':'result-title'}).text
    date= job.find('time',{'class':'result-date'}).text
    link= job.find('a',{'class':'result-title'}).get('href')
    job_response=requests.get(link)
    job_data= job_response.text
    job_soup=BeautifulSoup(job_data,'html.parser')
    job_description=job_soup.find('section',{'id':'postingbody'}).text
    
    print('Job title:',title,'\nDate:',date,'\nLink:',link)
    location_tag=job.find('span',{'class':'result-hood'})
    location= location_tag.text[1:-1] if location_tag else "N/A"
    print('Location:',location)
    print('Job description:',job_description)
    print()
# Out:
# Job title: DevOps Engineer
# Date: May 25
# Link: https://boston.craigslist.org/gbs/sof/d/roxbury-devops-engineer/7326968311.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# Join Hired and find your dream job as a DevOps Engineer at one of 10,000+ companies looking for candidates just like you.Companies on Hired apply to you, not the other way around. You'll receive salary and compensation details upfront - before the interview - and be able to choose from a variety of industries you’re interested in, to find a job you'll love in less than 2 weeks. DevOps/Site Reliability Engineer/Cloud Engineer/Systems Engineer  is gaining popularity in companies across all sectors, with DevOps Engineers/SRE leading the charge when it comes to putting best practices to use. They're  seen as the bridge between software and systems engineering to ensure products are released on time and within budget. DevOps Engineers implement and manage build infrastructure, build strategy (including container builds), and continuous delivery - while managing application configurations. They close the gap between the developer and the operations teams, wielding an arsenal of tech tools and experience to make the day-to-day operations on a company's tech team as smooth and efficient as possible.Having a hand in software releases that are quick, secure and of the highest quality is the goal of the DevOps Engineer and reflects well on their company.Join today because many companies on Hired are looking for DevOps Engineer with the following types of experiences:ResponsibilitiesDesigning and implementing solutions that make software deployments well-organized and automated.Coming up with effective results that bring developer & operations roles and goals together, and fostering a collaborative environment among all.Ensure product releases are high-quality and secure.Help automate processes to ensure efficiency, quality, and scalability.Liaise with various tech team members so product development and deployment are at their best.Having a firm understanding of business and client needs.Design, build, and maintain Continuous Improvement/Continuous Development (CI/CD), testing, and operations infrastructure.Nice to HavesExperience with Gitlab-CI, Terraform, OpenStack Heat, Cloud Formation, Kubernetes/Docker, Azure, AWS, GCP, Kafka/Storm, Python, Go, Java, Spinnaker, Elasticsearch, Prometheus, APIGEE, HAProxy, NGINX, Cassandra, Zabbix, and/or other toolsFamiliarity with infrastructure automation tools such as Puppet, Chef, Salt, Ansible, Jenkins, GoCD, Terraform, Artifactory, Nexus, InSpec, etcLinux & Microsoft System AdministrationStrong leadership and communication skillsBS or MS in Computer Science, Software Engineering or a related field, or equivalent work experience3+ years experience as a Software Engineer developing and maintaining an application3+ years experience with Linux administration (Full Stack or DevOps experience counts) Click here to apply.
#
# Job title: Software Engineer
# Date: May 25
# Link: https://boston.craigslist.org/gbs/sof/d/roxbury-software-engineer/7326968266.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# Join Hired and find your dream job as a Software Engineer at one of 10,000+ companies looking for candidates just like you.Companies on Hired apply to you! You'll receive salary and compensation details up front - before the interview. By joining Hired, we're confident that you'll find a job you'll love!Software Engineers continue to be one of the most exciting and sought after developer jobs available. Engineers code websites or applications on both the server and the user-facing side. It is a role that fuses both creative and practical concerns, as these engineers are responsible for everything the website user encounters, including scrolling functions and graphics, as well as crafting the logic, database interactions and server configuration on the application's Backend.In addition to programming the various features of server-side and user-side applications, software engineers are encouraged to upgrade and maintain both the Backend and Front-end as needed. As new technologies emerge and platforms are expanded, the role will likely transform to suit these changes.We need Software Engineering jobseekers on Hired who are results-oriented, multifaceted and can work independently or in a team environment, to get the job done.Common ResponsibilitiesThe development and maintenance of client-side and server-side applications.Working with a team of web developers, marketing teams and engineers to ensure the right look and vital features are included in your work.Crafting tests that will be implemented to keep software functional.Stay on top of growing technologies and engineering trends.Skills & Experiences Our Employers Need4+ Years of experience with Backend web development.4+ Years experience with Frontend web development.Proficiency with HTML and CSS.Code using languages such as JavaScript, Core MVC, and ASP.NET.An adroitness with SQL, Ruby, Ruby on Rails, Java for Front-End and Backend programming, Go Language, Swift, Docker, Azure, AngularJS and Angular 2.Building and accessing databases with NoSQL and Node.js.Understanding the ins-and-outs of HTTP protocols, developer tools, SSL certificates and web application architecture.Keeping track of changes made to code with Git version control system.These Would Also Be NiceGood communication skills.Thriving as a member of a team.Understanding the needed technology for web development.Keeping business needs in mind.Are you ready to find your next opportunity with Hired? Click here to apply.
#
# Job title: Data Science Lead - Stealth Startup
# Date: May 25
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-data-science-lead-stealth/7326963835.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# The Job
# A company in Stealth mode is looking for an exceptional Modeler / Data Scientist to help build a predictive algorithm model that utilizes lifestyle preferences and natural amenities to help people find communities where they can have a sense of belonging. Think of it as a much more personalized version of Zillow. You will be a core member of the Data Science team responsible for developing the data architecture framework, computational models, and statistical analyses. The work will not be like doing data science at Big Tech: the data will not be pristine but rather complex, messy, and challenging. What’s required for success will require more than throwing a series of models at the problem. We expect you to think in terms of hypotheses and experimental design like a scientist and have the drive and ingenuity of a hacker.
#
# Who We Are and What We Do
# Our mission is to help people find homes and communities where they’ll have a sense of belonging. In a world where many of us are working from home, people are in need of more space. Massive disruptions – the Covid-19 pandemic, wildfires, climate change, dynamic labor markets – are driving people to reconsider where they live, and what they value in a home. Existing real estate tools are not set up to can’t help people determine where they ought to live; they assume people already know. However, people face a huge and growing list of options, and need better tools to help them search and find the right place to live. We deliver data, analytics, and ultimately recommendations to help people find neighborhoods and homes that are a better fit than what they currently can find using existing tools.
#
# Our team consists of successful entrepreneurs who have had exits, hackers, data scientists, marketers, and get-shit-done types who genuinely see the opportunity to build a $100B super app. We are creating a culture in which we see ourselves as human beings before we are human “doings”. One expression of that is our commitment to using 1% of all revenue to build community centers in cities affected by gentrification and to create safe spaces where different kinds of conversations can occur than what occurs in the echo chambers of social media. We are also committed to inclusion, walking the talk, and utilizing technology for positive outcomes. We strongly encourage those with less represented backgrounds in technology to apply and those with massive egos who only care about making money without thinking about other people or the planet to not apply.
#
#
# Responsibilities
# Work closely with the CEO and CTO to oversee the development of a Proof of Concept (PoC) predictive algorithm model that will serve as the foundational technology for our Minimum Viable Product
# Link complex, heterogenous (spatial, tabular, high-frequency, static, etc.)
# Perform statistical analyses
# Develop weights and evaluation methods for determining effectiveness of algorithm
# Ensure statistical rigor and reproducibility of analyses and models by following relevant standard of practices and procedures writing clean code and conducting analyses with replication and validation in mind
# Provide interpretation of results and create customer-facing reports of modeling/statistical/actuarial work and present to internal and external stakeholders
#
# Your Profile—Who you are:
# You are passionate about utilizing technology to solve problems. You are curious, rigorous, and have integrity.
# You enjoy applying your skills to solve nontraditional problems, and are excited to explore and work with new types of data, methodologies, and analytical challenges. You are analytical, intellectually inquisitive, creative, and energetic. You are comfortable working both independently and through close collaboration. You are agile; build-test-validate-pivot is second nature to you.
#
# Basic Qualifications:
# 3+ years in proptech, consumer-facing real estate, or working with geospatial applications a plus
# Hands on experience applying machine learning techniques and building predictive models
# Excited to delve into data, no matter whether it’s clean, or messy/incomplete.
# Graduate degree (CS, AI, ML, or related technical field) and/or at least 3 years of experience in building ML models (ideal: experience building ML that operates within real-world systems)
# Experience working with diverse data types (big, small, sparse, empirical, modeled, etc.), which could include: images, structured and unstructured data, natural language, time-series (sensor data), audio.
# Thinking critically about how to work across and between different types of data, and to draw inferences between them
# Expertise with statistical software and associated programs
# Experience with building pipelines and scaling models with cloud computing platforms (Azure, AWS, or Google Cloud)
# Excellent oral and written communication skills
# Self-starter able to work independently and take ownership of work
# Ability to commit to 20+ hours of work per week for now before ramping up to full time
# Looking for mission-drive folks who want to build a $100B company but do right by our stakeholders
#
# Your Compensation:
# Significant equity commensurate to being a key early team-member and market-based salary once Seed round is completed
# Job title: Implementation Consultnat
# Date: May 25
# Link: https://boston.craigslist.org/bmw/sof/d/marlborough-implementation-consultnat/7326810798.html
# Location: (Marlborough
# Job description:
#
# QR Code Link to This Post
#
#
# CivicPlus is an informal, social workplace where enthusiasm and talent are rewarded. We are looking for an experienced professional with a software implementation and project management background. This is a fun, high-energy position that is at the forefront of CivicPlus’ success!
#
# CivicPlus is THE integrated technology platform for local government, working with over 4,000 local governments including municipalities, counties, and municipal departments. Inc. Magazine has selected CivicPlus as “One of the Fastest-Growing Privately Held Companies in the U.S.” since 2011.
#
# Due to all our recent product suite additions and more anticipated growth in the future, we are looking for talented individuals to join our team.
#
# We offer you....
#
# The chance to work with some of the best colleagues and most creative minds in the world
# Competitive pay and benefits
# The ability to leave a legacy used by millions of American and Canadian citizens
# The potential to work in an environment that is dedicated to teamwork, collaboration, and innovation.
#
# Job Overview:
#
# As the Implementation Consultant you will be responsible for managing all project related activities for an assigned customer. This includes project activities associated with new implementations and upgrades to existing application installations within Municipalities. The Implementation Consultant will follow the established project process with a keen attention to detail ensuring a successful project conclusion. They will guide the customer through the entire software implementation process. During the project, the Implementation Consultant will communicate with the customer in a professional manner and on a regular basis thus ensuring project results are being achieved and momentum towards the Go Live date is maintained. The overall objective of the Implementation Consultant is to ensure the highest level of customer satisfaction is achieved and final product delivered is at an optimal level of quality.
#
# This position be working within the CivicService division implementing SeeClickFix software.
#
# We’ll expect you to…
#
# Perform preparation activities required to begin project process and initiate project.
# Establish and maintain a professional relationship with customers throughout the application implementation effort.
# Conduct multiple structured formal meetings with customer to explain process, discuss configuration and review open customer action items as needed.
# Assist in configuring and testing of software to ensure it meets the defined project scope and client business requirements.
# Coordinate internal activities with Engineering, Client Success Managers and other Implementation Consultants.
# Provide end user instructional training sessions to show customers how to perform data update and site administrative activities.
# Actively contribute to the improvement and streamlining of the defined project process, including supporting documentation and project software.
# Assist in the training of new Implementation Consultants as required.
# Provide a level of service that results in a referenceable client.
#
# What you'll need to succeed...
#
# Strong interpersonal skills and team orientation.
# Strong written and verbal communication skills.
# Ability to multi-task, managing several customer issues or projects simultaneously.
# Strong organizational skill and keen attention on detail.
# Technical proficiency with strong personal computer skills.
# Working knowledge of Microsoft products including Word and Excel.
# Bachelor’s degree or commensurate experience.
# 1-2 years of relevant work experience.
#
#
# Employment Practices:
#
# CivicPlus is proud to be an Equal Employment Opportunity employer. At CivicPlus, we celebrate and support diversity for the benefit of our employees, products, clients and communities we serve.
# Upon receiving an offer of employment, candidates must complete required pre-employment screenings, which include a drug test and background screen. Offer of employment is contingent upon this post offer screening process. All testing will be conducted by a licensed independent administrator, which will follow testing standards and background screens in accordance with state law.
#
# Job title: Visual Studio Programming Expert /BASIC / C /Webforms /API
# Date: May 24
# Link: https://boston.craigslist.org/gbs/sof/d/auburndale-visual-studio-programming/7326520827.html
# Location: (Auburndale
# Job description:
#
# QR Code Link to This Post
#
#
# Local to Boston, you will be working with large enterprise customers in Massachusetts, who have chosen the expertise of our staff to help them with complicated enterprise solutions.  Since 1980's we have established over 400 customers who each have customized solutions written in Visual BASIC, Legacy BASIC, and have been converted into Visual Studio and C language.  Mostly it's a pleasure completing large web forms viewed by many employees of our customers, who provide instant feedback on new ideas you can implement for them. Our company designs web forms that reads SQL data.  The SQL data contains ERP Inventory Sales Order Information that is retrieved from QuickBooks.    Our goal is to create multiple lookup tables, using Microsoft Web Forms and SQL, and displaying this information for edit back into the SQL.
#
# Our team consists of programmers who write in  Visual Studio to create a "back end" API.  You will be using Microsoft Web Forms to design tables, lookups, customer entry screens, item pricing screens, all accessible by tablets or laptops.
#
# You should be familiar with techniques for API as needed, Java Scripting to read SQL data.  You must be able to work with bootstrap interface, and add-ons to Microsoft Visual Studio.
#
# Job title: In Class QA/BA Training & Placement in Boston Area
# Date: May 24
# Link: https://boston.craigslist.org/gbs/sof/d/malden-in-class-qa-ba-training/7326485408.html
# Location: (Malden, MA
# Job description:
#
# QR Code Link to This Post
#
#
# In Class QA/BA Training & Placement in Boston Area
# OPT/CPT ARE WELCOME TO APPLY
#
# We are actively looking for fresh Software Engineers, Business Analyst, Biomedical Engineers and people with Management degrees (STEM Degree only). We do provide H1B and Green card sponsorship for deserving candidates. Please forward to any of your friends who might be interested.
#
# NOTE: WE WORK ON ACTUAL PROJECTS AND NOT JUST DISPLAY SLIDES. HANDS ON TRAINING
#
# Topics Covered: In depth training on QTP/UFT, QC/ALM, Selenium, TestNG, CI/CD, SDLC Concepts, overall Test life cycle concepts etc.
#
# Degree Required
# We are looking for Fresh BS/MS/IT/MBA graduates in STEM fields for our multiple positions of Software Quality Engineers/Business Analysts /Pharmaceutical graduates and Biomedical Engineers.
# Required Skills:
# * Minimum of a Bachelor’s degree: Engineering/ Computer Science/ Management/Science/MBA/MS/MIS
# * Good communication/presentation skills
# * Knowledge of basic database applications, programming languages preferred.
# * Capable of learning new technologies in a fast paced environment
# * Ability to understand and effectively communicate at all management levels, technical
# dependencies, timeline impact.
# Benefits:
# * Base Pay of $58,000-$65,000 depending on experience
# * Advanced automation training by experienced and qualified instructors in Boston Area (Malden, MA)
# * Free training, Study material, interview preparation support.
# * FREE MENTORING AND JOB PLACEMENT with VERY AGGRESSIVE MARKETING.
# * COMPETITIVE SALARY WITH COMPLETE COMPANY SPONSORED BENEFITS,
# * INCREMENTS EVERY 6 MONTHS.
# * RELOCATION ASSISTANCE: We offer Relocation Assistance to help with the relocation costs while starting their project at client site.
# * E-Verified and Support for OPT Extensions
# * H1B Visa and Green Card sponsorship for qualified candidates
# * 100% SUCCESS RATE IN PROJECT PLACEMENT.
# * 100% APPROVAL RATE IN H1B AND GREEN CARD.
# ** Candidates should be open for relocation anywhere in USA ***
#
#
# Job title: Software Engineer
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/roxbury-software-engineer/7324312428.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# Join Hired and find your dream job as a Software Engineer at one of 10,000+ companies looking for candidates just like you.Companies on Hired apply to you! You'll receive salary and compensation details up front - before the interview. By joining Hired, we're confident that you'll find a job you'll love!Software Engineers continue to be one of the most exciting and sought after developer jobs available. Engineers code websites or applications on both the server and the user-facing side. It is a role that fuses both creative and practical concerns, as these engineers are responsible for everything the website user encounters, including scrolling functions and graphics, as well as crafting the logic, database interactions and server configuration on the application's Backend.In addition to programming the various features of server-side and user-side applications, software engineers are encouraged to upgrade and maintain both the Backend and Front-end as needed. As new technologies emerge and platforms are expanded, the role will likely transform to suit these changes.We need Software Engineering jobseekers on Hired who are results-oriented, multifaceted and can work independently or in a team environment, to get the job done.Common ResponsibilitiesThe development and maintenance of client-side and server-side applications.Working with a team of web developers, marketing teams and engineers to ensure the right look and vital features are included in your work.Crafting tests that will be implemented to keep software functional.Stay on top of growing technologies and engineering trends.Skills & Experiences Our Employers Need4+ Years of experience with Backend web development.4+ Years experience with Frontend web development.Proficiency with HTML and CSS.Code using languages such as JavaScript, Core MVC, and ASP.NET.An adroitness with SQL, Ruby, Ruby on Rails, Java for Front-End and Backend programming, Go Language, Swift, Docker, Azure, AngularJS and Angular 2.Building and accessing databases with NoSQL and Node.js.Understanding the ins-and-outs of HTTP protocols, developer tools, SSL certificates and web application architecture.Keeping track of changes made to code with Git version control system.These Would Also Be NiceGood communication skills.Thriving as a member of a team.Understanding the needed technology for web development.Keeping business needs in mind.Are you ready to find your next opportunity with Hired? Click here to apply.
# Job title: Data Science Fellowship
# Date: May 19
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7323959337.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 1000 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
#
# Job title: Product Management Fellowship
# Date: May 19
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7323959163.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 1000 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosproduct&utm_medium=job_board
#
#
# Job title: Software Engineering Fellowship
# Date: May 19
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7323958513.html
# Location: N/A
# Job description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 1000 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
